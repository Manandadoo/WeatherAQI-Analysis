# %%
import pandas as pd
aqi_data = pd.read_csv(r"/Users/anirudhgupta/Desktop/SEM 5/MiniProject/DE miniproject/datasets/Pune AQI 2017 (hourly).csv")
print(aqi_data)
# Out:
#                 From Date  PM2.5 (ug/m3)  PM10 (ug/m3)  NO (ug/m3)  \
# 0     2017-01-01 00:00:00          54.00         94.00       41.00
# 1     2017-01-01 01:00:00          49.25         78.50       36.40
# 2     2017-01-01 02:00:00          44.50         74.75       29.50
# 3     2017-01-01 03:00:00          48.75         74.00       33.38
# 4     2017-01-01 04:00:00          61.33         97.00       38.87
# ...                   ...            ...           ...         ...
# 8755  2017-12-31 19:00:00            NaN         79.33       52.00
# 8756  2017-12-31 20:00:00          44.00         86.00       82.43
# 8757  2017-12-31 21:00:00          54.00         95.00       84.97
# 8758  2017-12-31 22:00:00          53.00         89.67       84.90
# 8759  2017-12-31 23:00:00          46.00         85.00       98.60
#
#       NO2 (ug/m3)  NOx (ppb)  NH3 (ug/m3)  SO2 (ug/m3)  CO (mg/m3)  \
# 0          115.57      94.83        10.17         3.67        0.64
# 1          113.73      90.12        10.22         2.80        0.58
# 2          106.70      80.70         9.77         2.38        0.51
# 3          112.67      87.08         9.30         1.85        0.57
# 4          119.80      95.37         9.00         5.07        0.62
# ...           ...        ...          ...          ...         ...
# 8755        69.00      78.95         7.40         5.45        0.58
# 8756        87.10     113.33         7.85         6.43        0.66
# 8757        83.00     113.30         9.87         6.35        0.66
# 8758        85.15     114.33         9.55         6.88        0.51
# 8759        91.60     128.90         9.20         6.73        0.50
#
#       Ozone (ug/m3)  ...  Temp (degree C)  RH (%)  WS (m/s)  WD (deg)  \
# 0             14.63  ...            32.43   86.00      1.47    275.00
# 1             14.90  ...            32.48   86.00      1.55    294.25
# 2             14.50  ...            32.53   86.00      1.12    276.50
# 3             11.62  ...            32.85   85.25      1.23    276.00
# 4             18.90  ...            32.53   84.67      0.87    278.67
# ...             ...  ...              ...     ...       ...       ...
# 8755          14.33  ...            30.10   80.75      1.88    204.50
# 8756           9.05  ...            30.08   79.00      1.53    204.25
# 8757           7.20  ...            30.10   76.25      1.28    207.25
# 8758           5.83  ...            30.05   73.50      1.38    197.25
# 8759           2.53  ...            30.07   70.00      1.13    193.33
#
#       SR (W/mt2)  BP (mmHg)  VWS (m/s)  Xylene (ug/m3)  RF (mm)  AT (degree C)
# 0           8.00        NaN      -0.10            1.07     0.00          16.87
# 1           9.00        NaN      -0.10            0.92     0.00          16.63
# 2           9.00        NaN      -0.10            0.70     0.00          16.32
# 3           8.25        NaN      -0.10            0.20     0.25          16.20
# 4           8.00        NaN      -0.10            0.23     0.00          16.23
# ...          ...        ...        ...             ...      ...            ...
# 8755        3.00        NaN       0.00            0.35     0.00          18.32
# 8756        3.00        NaN       0.00            0.40     0.00          18.03
# 8757        3.00        NaN       0.00            0.85     0.00          17.90
# 8758        3.00        NaN       0.03            0.85     0.00          17.95
# 8759        3.00        NaN       0.00            0.65     0.00          17.97
#
# [8760 rows x 22 columns]

# %%
import pandas as pd
weather_data = pd.read_csv(r"/Users/anirudhgupta/Desktop/SEM 5/MiniProject/DE miniproject/datasets/Pune 2017 weather(every hour).csv")
print(weather_data)
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     01-01-2017 00:00        31        17             0     11.0        6
# 1     01-01-2017 01:00        31        17             0     11.0        6
# 2     01-01-2017 02:00        31        17             0     11.0        6
# 3     01-01-2017 03:00        31        17             0     11.0        6
# 4     01-01-2017 04:00        31        17             0     11.0        6
# ...                ...       ...       ...           ...      ...      ...
# 8755  31-12-2017 19:00        30        18             0     11.0        6
# 8756  31-12-2017 20:00        30        18             0     11.0        6
# 8757  31-12-2017 21:00        30        18             0     11.0        6
# 8758  31-12-2017 22:00        30        18             0     11.0        6
# 8759  31-12-2017 23:00        30        18             0     11.0        6
#
#       moon_illumination moonrise  moonset  sunrise  ... cloudcover  humidity  \
# 0                    20  9:15 AM  8:58 PM  7:07 AM  ...          1        62
# 1                    20  9:15 AM  8:58 PM  7:07 AM  ...          1        63
# 2                    20  9:15 AM  8:58 PM  7:07 AM  ...          0        63
# 3                    20  9:15 AM  8:58 PM  7:07 AM  ...          0        64
# 4                    20  9:15 AM  8:58 PM  7:07 AM  ...          1        57
# ...                 ...      ...      ...      ...  ...        ...       ...
# 8755                 86  4:33 PM  4:53 AM  7:07 AM  ...          2        44
# 8756                 86  4:33 PM  4:53 AM  7:07 AM  ...          2        45
# 8757                 86  4:33 PM  4:53 AM  7:07 AM  ...          2        46
# 8758                 86  4:33 PM  4:53 AM  7:07 AM  ...          2        48
# 8759                 86  4:33 PM  4:53 AM  7:07 AM  ...          2        50
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 0          0.0      1014     18          10             71              2
# 1          0.0      1014     18          10             82              2
# 2          0.0      1014     18          10             94              3
# 3          0.0      1014     17          10            105              3
# 4          0.0      1014     19          10            110              4
# ...        ...       ...    ...         ...            ...            ...
# 8755       0.0      1012     21          10             99              2
# 8756       0.0      1012     21          10            193              3
# 8757       0.0      1012     20          10            287              4
# 8758       0.0      1012     19          10            201              3
# 8759       0.0      1011     19          10            114              3
#
#       location  Unnamed: 25
# 0         pune          NaN
# 1         pune          NaN
# 2         pune          NaN
# 3         pune          NaN
# 4         pune          NaN
# ...        ...          ...
# 8755      pune          NaN
# 8756      pune          NaN
# 8757      pune          NaN
# 8758      pune          NaN
# 8759      pune          NaN
#
# [8760 rows x 26 columns]

# %%
weather_data['date_time'] = pd.to_datetime(weather_data['date_time'], format='%d-%m-%Y %H:%M')
aqi_data['From Date'] = pd.to_datetime(aqi_data['From Date'], format='%Y-%m-%d %H:%M:%S')

# %%
merged_data = pd.merge(aqi_data, weather_data, right_on='date_time', left_on='From Date')
print (merged_data)
# Out:
#                From Date  PM2.5 (ug/m3)  PM10 (ug/m3)  NO (ug/m3)  \
# 0    2017-01-01 00:00:00          54.00         94.00       41.00
# 1    2017-01-01 01:00:00          49.25         78.50       36.40
# 2    2017-01-01 02:00:00          44.50         74.75       29.50
# 3    2017-01-01 03:00:00          48.75         74.00       33.38
# 4    2017-01-01 04:00:00          61.33         97.00       38.87
# ...                  ...            ...           ...         ...
# 8755 2017-12-31 19:00:00            NaN         79.33       52.00
# 8756 2017-12-31 20:00:00          44.00         86.00       82.43
# 8757 2017-12-31 21:00:00          54.00         95.00       84.97
# 8758 2017-12-31 22:00:00          53.00         89.67       84.90
# 8759 2017-12-31 23:00:00          46.00         85.00       98.60
#
#       NO2 (ug/m3)  NOx (ppb)  NH3 (ug/m3)  SO2 (ug/m3)  CO (mg/m3)  \
# 0          115.57      94.83        10.17         3.67        0.64
# 1          113.73      90.12        10.22         2.80        0.58
# 2          106.70      80.70         9.77         2.38        0.51
# 3          112.67      87.08         9.30         1.85        0.57
# 4          119.80      95.37         9.00         5.07        0.62
# ...           ...        ...          ...          ...         ...
# 8755        69.00      78.95         7.40         5.45        0.58
# 8756        87.10     113.33         7.85         6.43        0.66
# 8757        83.00     113.30         9.87         6.35        0.66
# 8758        85.15     114.33         9.55         6.88        0.51
# 8759        91.60     128.90         9.20         6.73        0.50
#
#       Ozone (ug/m3)  ...  cloudcover  humidity  precipMM  pressure  tempC  \
# 0             14.63  ...           1        62       0.0      1014     18
# 1             14.90  ...           1        63       0.0      1014     18
# 2             14.50  ...           0        63       0.0      1014     18
# 3             11.62  ...           0        64       0.0      1014     17
# 4             18.90  ...           1        57       0.0      1014     19
# ...             ...  ...         ...       ...       ...       ...    ...
# 8755          14.33  ...           2        44       0.0      1012     21
# 8756           9.05  ...           2        45       0.0      1012     21
# 8757           7.20  ...           2        46       0.0      1012     20
# 8758           5.83  ...           2        48       0.0      1012     19
# 8759           2.53  ...           2        50       0.0      1011     19
#
#       visibility  winddirDegree  windspeedKmph  location  Unnamed: 25
# 0             10             71              2      pune          NaN
# 1             10             82              2      pune          NaN
# 2             10             94              3      pune          NaN
# 3             10            105              3      pune          NaN
# 4             10            110              4      pune          NaN
# ...          ...            ...            ...       ...          ...
# 8755          10             99              2      pune          NaN
# 8756          10            193              3      pune          NaN
# 8757          10            287              4      pune          NaN
# 8758          10            201              3      pune          NaN
# 8759          10            114              3      pune          NaN
#
# [8760 rows x 48 columns]

# %%
merged_data = merged_data.drop(merged_data.columns[-1], axis=1)
print(merged_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   From Date          8760 non-null   datetime64[ns]
#  1   PM2.5 (ug/m3)      7746 non-null   float64
#  2   PM10 (ug/m3)       7720 non-null   float64
#  3   NO (ug/m3)         7688 non-null   float64
#  4   NO2 (ug/m3)        7686 non-null   float64
#  5   NOx (ppb)          7793 non-null   float64
#  6   NH3 (ug/m3)        6236 non-null   float64
#  7   SO2 (ug/m3)        7430 non-null   float64
#  8   CO (mg/m3)         7802 non-null   float64
#  9   Ozone (ug/m3)      7776 non-null   float64
#  10  Benzene (ug/m3)    7802 non-null   float64
#  11  Toluene (ug/m3)    7802 non-null   float64
#  12  Temp (degree C)    7619 non-null   float64
#  13  RH (%)             7771 non-null   float64
#  14  WS (m/s)           7768 non-null   float64
#  15  WD (deg)           7769 non-null   float64
#  16  SR (W/mt2)         7801 non-null   float64
#  17  BP (mmHg)          1176 non-null   float64
#  18  VWS (m/s)          7795 non-null   float64
#  19  Xylene (ug/m3)     7789 non-null   float64
#  20  RF (mm)            7716 non-null   float64
#  21  AT (degree C)      7744 non-null   float64
#  22  date_time          8760 non-null   datetime64[ns]
#  23  maxtempC           8760 non-null   int64
#  24  mintempC           8760 non-null   int64
#  25  totalSnow_cm       8760 non-null   int64
#  26  sunHour            8760 non-null   float64
#  27  uvIndex            8760 non-null   int64
#  28  moon_illumination  8760 non-null   int64
#  29  moonrise           8760 non-null   object
#  30  moonset            8760 non-null   object
#  31  sunrise            8760 non-null   object
#  32  sunset             8760 non-null   object
#  33  DewPointC          8760 non-null   int64
#  34  FeelsLikeC         8760 non-null   int64
#  35  HeatIndexC         8760 non-null   int64
#  36  WindChillC         8760 non-null   int64
#  37  WindGustKmph       8760 non-null   int64
#  38  cloudcover         8760 non-null   int64
#  39  humidity           8760 non-null   int64
#  40  precipMM           8760 non-null   float64
#  41  pressure           8760 non-null   int64
#  42  tempC              8760 non-null   int64
#  43  visibility         8760 non-null   int64
#  44  winddirDegree      8760 non-null   int64
#  45  windspeedKmph      8760 non-null   int64
#  46  location           8760 non-null   object
# dtypes: datetime64[ns](2), float64(23), int64(17), object(5)
# memory usage: 3.1+ MB
# None

# %%
import numpy as np
numeric_dataset = merged_data.select_dtypes(include=[np.number, 'datetime64[ns]'])
print(numeric_dataset)
# Out:
#                From Date  PM2.5 (ug/m3)  PM10 (ug/m3)  NO (ug/m3)  \
# 0    2017-01-01 00:00:00          54.00         94.00       41.00
# 1    2017-01-01 01:00:00          49.25         78.50       36.40
# 2    2017-01-01 02:00:00          44.50         74.75       29.50
# 3    2017-01-01 03:00:00          48.75         74.00       33.38
# 4    2017-01-01 04:00:00          61.33         97.00       38.87
# ...                  ...            ...           ...         ...
# 8755 2017-12-31 19:00:00            NaN         79.33       52.00
# 8756 2017-12-31 20:00:00          44.00         86.00       82.43
# 8757 2017-12-31 21:00:00          54.00         95.00       84.97
# 8758 2017-12-31 22:00:00          53.00         89.67       84.90
# 8759 2017-12-31 23:00:00          46.00         85.00       98.60
#
#       NO2 (ug/m3)  NOx (ppb)  NH3 (ug/m3)  SO2 (ug/m3)  CO (mg/m3)  \
# 0          115.57      94.83        10.17         3.67        0.64
# 1          113.73      90.12        10.22         2.80        0.58
# 2          106.70      80.70         9.77         2.38        0.51
# 3          112.67      87.08         9.30         1.85        0.57
# 4          119.80      95.37         9.00         5.07        0.62
# ...           ...        ...          ...          ...         ...
# 8755        69.00      78.95         7.40         5.45        0.58
# 8756        87.10     113.33         7.85         6.43        0.66
# 8757        83.00     113.30         9.87         6.35        0.66
# 8758        85.15     114.33         9.55         6.88        0.51
# 8759        91.60     128.90         9.20         6.73        0.50
#
#       Ozone (ug/m3)  ...  WindChillC  WindGustKmph  cloudcover  humidity  \
# 0             14.63  ...          18             4           1        62
# 1             14.90  ...          18             5           1        63
# 2             14.50  ...          18             5           0        63
# 3             11.62  ...          17             6           0        64
# 4             18.90  ...          19             7           1        57
# ...             ...  ...         ...           ...         ...       ...
# 8755          14.33  ...          21             9           2        44
# 8756           9.05  ...          21             9           2        45
# 8757           7.20  ...          20             7           2        46
# 8758           5.83  ...          19             6           2        48
# 8759           2.53  ...          19             9           2        50
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph
# 0          0.0      1014     18          10             71              2
# 1          0.0      1014     18          10             82              2
# 2          0.0      1014     18          10             94              3
# 3          0.0      1014     17          10            105              3
# 4          0.0      1014     19          10            110              4
# ...        ...       ...    ...         ...            ...            ...
# 8755       0.0      1012     21          10             99              2
# 8756       0.0      1012     21          10            193              3
# 8757       0.0      1012     20          10            287              4
# 8758       0.0      1012     19          10            201              3
# 8759       0.0      1011     19          10            114              3
#
# [8760 rows x 42 columns]

# %%
missing_values = numeric_dataset.isnull().sum()
print(missing_values)
# Out:
# From Date               0
# PM2.5 (ug/m3)        1014
# PM10 (ug/m3)         1040
# NO (ug/m3)           1072
# NO2 (ug/m3)          1074
# NOx (ppb)             967
# NH3 (ug/m3)          2524
# SO2 (ug/m3)          1330
# CO (mg/m3)            958
# Ozone (ug/m3)         984
# Benzene (ug/m3)       958
# Toluene (ug/m3)       958
# Temp (degree C)      1141
# RH (%)                989
# WS (m/s)              992
# WD (deg)              991
# SR (W/mt2)            959
# BP (mmHg)            7584
# VWS (m/s)             965
# Xylene (ug/m3)        971
# RF (mm)              1044
# AT (degree C)        1016
# date_time               0
# maxtempC                0
# mintempC                0
# totalSnow_cm            0
# sunHour                 0
# uvIndex                 0
# moon_illumination       0
# DewPointC               0
# FeelsLikeC              0
# HeatIndexC              0
# WindChillC              0
# WindGustKmph            0
# cloudcover              0
# humidity                0
# precipMM                0
# pressure                0
# tempC                   0
# visibility              0
# winddirDegree           0
# windspeedKmph           0
# dtype: int64

# %%
numeric_dataset = numeric_dataset.drop(numeric_dataset.columns[0], axis=1)
print(numeric_dataset)
# Out:
#       PM2.5 (ug/m3)  PM10 (ug/m3)  NO (ug/m3)  NO2 (ug/m3)  NOx (ppb)  \
# 0             54.00         94.00       41.00       115.57      94.83
# 1             49.25         78.50       36.40       113.73      90.12
# 2             44.50         74.75       29.50       106.70      80.70
# 3             48.75         74.00       33.38       112.67      87.08
# 4             61.33         97.00       38.87       119.80      95.37
# ...             ...           ...         ...          ...        ...
# 8755            NaN         79.33       52.00        69.00      78.95
# 8756          44.00         86.00       82.43        87.10     113.33
# 8757          54.00         95.00       84.97        83.00     113.30
# 8758          53.00         89.67       84.90        85.15     114.33
# 8759          46.00         85.00       98.60        91.60     128.90
#
#       NH3 (ug/m3)  SO2 (ug/m3)  CO (mg/m3)  Ozone (ug/m3)  Benzene (ug/m3)  \
# 0           10.17         3.67        0.64          14.63             2.70
# 1           10.22         2.80        0.58          14.90             2.20
# 2            9.77         2.38        0.51          14.50             1.97
# 3            9.30         1.85        0.57          11.62             1.82
# 4            9.00         5.07        0.62          18.90             1.70
# ...           ...          ...         ...            ...              ...
# 8755         7.40         5.45        0.58          14.33             1.20
# 8756         7.85         6.43        0.66           9.05             1.65
# 8757         9.87         6.35        0.66           7.20             1.80
# 8758         9.55         6.88        0.51           5.83             1.85
# 8759         9.20         6.73        0.50           2.53             1.80
#
#       ...  WindChillC  WindGustKmph  cloudcover  humidity  precipMM  pressure  \
# 0     ...          18             4           1        62       0.0      1014
# 1     ...          18             5           1        63       0.0      1014
# 2     ...          18             5           0        63       0.0      1014
# 3     ...          17             6           0        64       0.0      1014
# 4     ...          19             7           1        57       0.0      1014
# ...   ...         ...           ...         ...       ...       ...       ...
# 8755  ...          21             9           2        44       0.0      1012
# 8756  ...          21             9           2        45       0.0      1012
# 8757  ...          20             7           2        46       0.0      1012
# 8758  ...          19             6           2        48       0.0      1012
# 8759  ...          19             9           2        50       0.0      1011
#
#       tempC  visibility  winddirDegree  windspeedKmph
# 0        18          10             71              2
# 1        18          10             82              2
# 2        18          10             94              3
# 3        17          10            105              3
# 4        19          10            110              4
# ...     ...         ...            ...            ...
# 8755     21          10             99              2
# 8756     21          10            193              3
# 8757     20          10            287              4
# 8758     19          10            201              3
# 8759     19          10            114              3
#
# [8760 rows x 41 columns]

# %%
numeric_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PM2.5 (ug/m3)      7746 non-null   float64
#  1   PM10 (ug/m3)       7720 non-null   float64
#  2   NO (ug/m3)         7688 non-null   float64
#  3   NO2 (ug/m3)        7686 non-null   float64
#  4   NOx (ppb)          7793 non-null   float64
#  5   NH3 (ug/m3)        6236 non-null   float64
#  6   SO2 (ug/m3)        7430 non-null   float64
#  7   CO (mg/m3)         7802 non-null   float64
#  8   Ozone (ug/m3)      7776 non-null   float64
#  9   Benzene (ug/m3)    7802 non-null   float64
#  10  Toluene (ug/m3)    7802 non-null   float64
#  11  Temp (degree C)    7619 non-null   float64
#  12  RH (%)             7771 non-null   float64
#  13  WS (m/s)           7768 non-null   float64
#  14  WD (deg)           7769 non-null   float64
#  15  SR (W/mt2)         7801 non-null   float64
#  16  BP (mmHg)          1176 non-null   float64
#  17  VWS (m/s)          7795 non-null   float64
#  18  Xylene (ug/m3)     7789 non-null   float64
#  19  RF (mm)            7716 non-null   float64
#  20  AT (degree C)      7744 non-null   float64
#  21  date_time          8760 non-null   datetime64[ns]
#  22  maxtempC           8760 non-null   int64
#  23  mintempC           8760 non-null   int64
#  24  totalSnow_cm       8760 non-null   int64
#  25  sunHour            8760 non-null   float64
#  26  uvIndex            8760 non-null   int64
#  27  moon_illumination  8760 non-null   int64
#  28  DewPointC          8760 non-null   int64
#  29  FeelsLikeC         8760 non-null   int64
#  30  HeatIndexC         8760 non-null   int64
#  31  WindChillC         8760 non-null   int64
#  32  WindGustKmph       8760 non-null   int64
#  33  cloudcover         8760 non-null   int64
#  34  humidity           8760 non-null   int64
#  35  precipMM           8760 non-null   float64
#  36  pressure           8760 non-null   int64
#  37  tempC              8760 non-null   int64
#  38  visibility         8760 non-null   int64
#  39  winddirDegree      8760 non-null   int64
#  40  windspeedKmph      8760 non-null   int64
# dtypes: datetime64[ns](1), float64(23), int64(17)
# memory usage: 2.7 MB

# %%
import pandas as pd

# Set the datetime column as the index if not already done
numeric_dataset.set_index('date_time', inplace=True)

# Resample the data by week and calculate the weekly mean for each column
weekly_mean = numeric_dataset.resample('W').mean()

# Fill missing values with the corresponding week's mean
numeric_dataset = numeric_dataset.resample('W').apply(lambda week: week.fillna(week.mean()))

# %%
missing_values = numeric_dataset.isnull().sum()
print(missing_values)
# Out:
# PM2.5 (ug/m3)         336
# PM10 (ug/m3)          336
# NO (ug/m3)            336
# NO2 (ug/m3)           336
# NOx (ppb)             336
# NH3 (ug/m3)          2016
# SO2 (ug/m3)           336
# CO (mg/m3)            336
# Ozone (ug/m3)         336
# Benzene (ug/m3)       336
# Toluene (ug/m3)       336
# Temp (degree C)       336
# RH (%)                336
# WS (m/s)              336
# WD (deg)              336
# SR (W/mt2)            336
# BP (mmHg)            6744
# VWS (m/s)             336
# Xylene (ug/m3)        336
# RF (mm)               336
# AT (degree C)         336
# maxtempC                0
# mintempC                0
# totalSnow_cm            0
# sunHour                 0
# uvIndex                 0
# moon_illumination       0
# DewPointC               0
# FeelsLikeC              0
# HeatIndexC              0
# WindChillC              0
# WindGustKmph            0
# cloudcover              0
# humidity                0
# precipMM                0
# pressure                0
# tempC                   0
# visibility              0
# winddirDegree           0
# windspeedKmph           0
# dtype: int64

# %%
# For any remaining missing values, apply forward or backward filling
numeric_dataset = numeric_dataset.ffill().bfill()

# %%
missing_values = numeric_dataset.isnull().sum()
print(missing_values)
# Out:
# PM2.5 (ug/m3)        0
# PM10 (ug/m3)         0
# NO (ug/m3)           0
# NO2 (ug/m3)          0
# NOx (ppb)            0
# NH3 (ug/m3)          0
# SO2 (ug/m3)          0
# CO (mg/m3)           0
# Ozone (ug/m3)        0
# Benzene (ug/m3)      0
# Toluene (ug/m3)      0
# Temp (degree C)      0
# RH (%)               0
# WS (m/s)             0
# WD (deg)             0
# SR (W/mt2)           0
# BP (mmHg)            0
# VWS (m/s)            0
# Xylene (ug/m3)       0
# RF (mm)              0
# AT (degree C)        0
# maxtempC             0
# mintempC             0
# totalSnow_cm         0
# sunHour              0
# uvIndex              0
# moon_illumination    0
# DewPointC            0
# FeelsLikeC           0
# HeatIndexC           0
# WindChillC           0
# WindGustKmph         0
# cloudcover           0
# humidity             0
# precipMM             0
# pressure             0
# tempC                0
# visibility           0
# winddirDegree        0
# windspeedKmph        0
# dtype: int64

# %%
import pandas as pd

# Function to calculate AQI for a single pollutant based on its concentration and breakpoints
def calculate_individual_aqi(concentration, breakpoints):
    for (C_lo, C_hi, I_lo, I_hi) in breakpoints:
        if C_lo <= concentration <= C_hi:
            return ((I_hi - I_lo) / (C_hi - C_lo)) * (concentration - C_lo) + I_lo
    return None

# Breakpoints for PM2.5 (in µg/m³)
pm25_breakpoints = [
    (0, 30, 0, 50), (31, 60, 51, 100), (61, 90, 101, 200),
    (91, 120, 201, 300), (121, 250, 301, 400), (251, 500, 401, 500)
]

# Breakpoints for PM10 (in µg/m³)
pm10_breakpoints = [
    (0, 50, 0, 50), (51, 100, 51, 100), (101, 250, 101, 200),
    (251, 350, 201, 300), (351, 430, 301, 400), (431, 600, 401, 500)
]

# Breakpoints for O3 (in ppb)
o3_breakpoints = [
    (0, 50, 0, 50), (51, 100, 51, 100), (101, 168, 101, 200),
    (169, 208, 201, 300), (209, 748, 301, 400)
]

# Breakpoints for NO2 (in ppb)
no2_breakpoints = [
    (0, 40, 0, 50), (41, 80, 51, 100), (81, 180, 101, 200),
    (181, 280, 201, 300), (281, 400, 301, 400), (401, 1000, 401, 500)
]

# Breakpoints for SO2 (in ppb)
so2_breakpoints = [
    (0, 40, 0, 50), (41, 80, 51, 100), (81, 380, 101, 200),
    (381, 800, 201, 300), (801, 1600, 301, 400), (1601, 10000, 401, 500)
]

# Breakpoints for CO (in mg/m³)
co_breakpoints = [
    (0, 1, 0, 50), (1.1, 2, 51, 100), (2.1, 10, 101, 200),
    (10.1, 17, 201, 300), (17.1, 34, 301, 400), (34.1, 50, 401, 500)
]

# Function to calculate the overall AQI for a row based on pollutant concentrations
def calculate_aqi_for_row(row):
    # Calculate AQI for each pollutant using the dataset's specific field names
    pm25_aqi = calculate_individual_aqi(row['PM2.5 (ug/m3)'], pm25_breakpoints) if 'PM2.5 (ug/m3)' in row else None
    pm10_aqi = calculate_individual_aqi(row['PM10 (ug/m3)'], pm10_breakpoints) if 'PM10 (ug/m3)' in row else None
    o3_aqi = calculate_individual_aqi(row['Ozone (ug/m3)'], o3_breakpoints) if 'Ozone (ug/m3)' in row else None
    no2_aqi = calculate_individual_aqi(row['NO2 (ug/m3)'], no2_breakpoints) if 'NO2 (ug/m3)' in row else None
    so2_aqi = calculate_individual_aqi(row['SO2 (ug/m3)'], so2_breakpoints) if 'SO2 (ug/m3)' in row else None
    co_aqi = calculate_individual_aqi(row['CO (mg/m3)'], co_breakpoints) if 'CO (mg/m3)' in row else None

    # Return a dictionary of AQI values for each pollutant
    return {
        'PM2.5 AQI': pm25_aqi,
        'PM10 AQI': pm10_aqi,
        'Ozone AQI': o3_aqi,
        'NO2 AQI': no2_aqi,
        'SO2 AQI': so2_aqi,
        'CO AQI': co_aqi,
        'Overall AQI': max(filter(None, [pm25_aqi, pm10_aqi, o3_aqi, no2_aqi, so2_aqi, co_aqi]), default=None)
    }

# Assuming df is your dataframe with hourly AQI data
# Apply the function to calculate AQI for each row and store results in a new dataframe
aqi_results = numeric_dataset.apply(calculate_aqi_for_row, axis=1, result_type='expand')

# Combine the original dataframe with the AQI results
numeric_dataset = pd.concat([numeric_dataset, aqi_results], axis=1)

# Copying 'tempC' column to a new column with a different name 'temperature'
numeric_dataset['AQI'] = numeric_dataset['Overall AQI']

# Print the AQI values for each parameter
print(numeric_dataset[['AQI', 'PM2.5 AQI', 'PM10 AQI', 'Ozone AQI', 'NO2 AQI', 'SO2 AQI', 'CO AQI', 'Overall AQI']])
# Out:
#                             AQI   PM2.5 AQI  PM10 AQI  Ozone AQI     NO2 AQI  \
# date_time
# 2017-01-01 00:00:00  135.570000   89.862069     94.00      14.63  135.570000
# 2017-01-01 01:00:00  133.730000   81.836207     78.50      14.90  133.730000
# 2017-01-01 02:00:00  126.700000   73.810345     74.75      14.50  126.700000
# 2017-01-01 03:00:00  132.670000   80.991379     74.00      11.62  132.670000
# 2017-01-01 04:00:00  139.800000  102.126552     97.00      18.90  139.800000
# ...                         ...         ...       ...        ...         ...
# 2017-12-31 19:00:00   97.903917   97.903917     79.33      14.33   86.179487
# 2017-12-31 20:00:00  107.100000   72.965517     86.00       9.05  107.100000
# 2017-12-31 21:00:00  103.000000   89.862069     95.00       7.20  103.000000
# 2017-12-31 22:00:00  105.150000   88.172414     89.67       5.83  105.150000
# 2017-12-31 23:00:00  111.600000   76.344828     85.00       2.53  111.600000
#
#                      SO2 AQI  CO AQI  Overall AQI
# date_time
# 2017-01-01 00:00:00   4.5875    32.0   135.570000
# 2017-01-01 01:00:00   3.5000    29.0   133.730000
# 2017-01-01 02:00:00   2.9750    25.5   126.700000
# 2017-01-01 03:00:00   2.3125    28.5   132.670000
# 2017-01-01 04:00:00   6.3375    31.0   139.800000
# ...                      ...     ...          ...
# 2017-12-31 19:00:00   6.8125    29.0    97.903917
# 2017-12-31 20:00:00   8.0375    33.0   107.100000
# 2017-12-31 21:00:00   7.9375    33.0   103.000000
# 2017-12-31 22:00:00   8.6000    25.5   105.150000
# 2017-12-31 23:00:00   8.4125    25.0   111.600000
#
# [8760 rows x 8 columns]

# %%
print(numeric_dataset)
# Out:
#                      PM2.5 (ug/m3)  PM10 (ug/m3)  NO (ug/m3)  NO2 (ug/m3)  \
# date_time
# 2017-01-01 00:00:00      54.000000         94.00       41.00       115.57
# 2017-01-01 01:00:00      49.250000         78.50       36.40       113.73
# 2017-01-01 02:00:00      44.500000         74.75       29.50       106.70
# 2017-01-01 03:00:00      48.750000         74.00       33.38       112.67
# 2017-01-01 04:00:00      61.330000         97.00       38.87       119.80
# ...                            ...           ...         ...          ...
# 2017-12-31 19:00:00      58.759461         79.33       52.00        69.00
# 2017-12-31 20:00:00      44.000000         86.00       82.43        87.10
# 2017-12-31 21:00:00      54.000000         95.00       84.97        83.00
# 2017-12-31 22:00:00      53.000000         89.67       84.90        85.15
# 2017-12-31 23:00:00      46.000000         85.00       98.60        91.60
#
#                      NOx (ppb)  NH3 (ug/m3)  SO2 (ug/m3)  CO (mg/m3)  \
# date_time
# 2017-01-01 00:00:00      94.83        10.17         3.67        0.64
# 2017-01-01 01:00:00      90.12        10.22         2.80        0.58
# 2017-01-01 02:00:00      80.70         9.77         2.38        0.51
# 2017-01-01 03:00:00      87.08         9.30         1.85        0.57
# 2017-01-01 04:00:00      95.37         9.00         5.07        0.62
# ...                        ...          ...          ...         ...
# 2017-12-31 19:00:00      78.95         7.40         5.45        0.58
# 2017-12-31 20:00:00     113.33         7.85         6.43        0.66
# 2017-12-31 21:00:00     113.30         9.87         6.35        0.66
# 2017-12-31 22:00:00     114.33         9.55         6.88        0.51
# 2017-12-31 23:00:00     128.90         9.20         6.73        0.50
#
#                      Ozone (ug/m3)  Benzene (ug/m3)  ...  winddirDegree  \
# date_time                                            ...
# 2017-01-01 00:00:00          14.63             2.70  ...             71
# 2017-01-01 01:00:00          14.90             2.20  ...             82
# 2017-01-01 02:00:00          14.50             1.97  ...             94
# 2017-01-01 03:00:00          11.62             1.82  ...            105
# 2017-01-01 04:00:00          18.90             1.70  ...            110
# ...                            ...              ...  ...            ...
# 2017-12-31 19:00:00          14.33             1.20  ...             99
# 2017-12-31 20:00:00           9.05             1.65  ...            193
# 2017-12-31 21:00:00           7.20             1.80  ...            287
# 2017-12-31 22:00:00           5.83             1.85  ...            201
# 2017-12-31 23:00:00           2.53             1.80  ...            114
#
#                      windspeedKmph   PM2.5 AQI  PM10 AQI  Ozone AQI  \
# date_time
# 2017-01-01 00:00:00              2   89.862069     94.00      14.63
# 2017-01-01 01:00:00              2   81.836207     78.50      14.90
# 2017-01-01 02:00:00              3   73.810345     74.75      14.50
# 2017-01-01 03:00:00              3   80.991379     74.00      11.62
# 2017-01-01 04:00:00              4  102.126552     97.00      18.90
# ...                            ...         ...       ...        ...
# 2017-12-31 19:00:00              2   97.903917     79.33      14.33
# 2017-12-31 20:00:00              3   72.965517     86.00       9.05
# 2017-12-31 21:00:00              4   89.862069     95.00       7.20
# 2017-12-31 22:00:00              3   88.172414     89.67       5.83
# 2017-12-31 23:00:00              3   76.344828     85.00       2.53
#
#                         NO2 AQI  SO2 AQI  CO AQI  Overall AQI         AQI
# date_time
# 2017-01-01 00:00:00  135.570000   4.5875    32.0   135.570000  135.570000
# 2017-01-01 01:00:00  133.730000   3.5000    29.0   133.730000  133.730000
# 2017-01-01 02:00:00  126.700000   2.9750    25.5   126.700000  126.700000
# 2017-01-01 03:00:00  132.670000   2.3125    28.5   132.670000  132.670000
# 2017-01-01 04:00:00  139.800000   6.3375    31.0   139.800000  139.800000
# ...                         ...      ...     ...          ...         ...
# 2017-12-31 19:00:00   86.179487   6.8125    29.0    97.903917   97.903917
# 2017-12-31 20:00:00  107.100000   8.0375    33.0   107.100000  107.100000
# 2017-12-31 21:00:00  103.000000   7.9375    33.0   103.000000  103.000000
# 2017-12-31 22:00:00  105.150000   8.6000    25.5   105.150000  105.150000
# 2017-12-31 23:00:00  111.600000   8.4125    25.0   111.600000  111.600000
#
# [8760 rows x 48 columns]

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# Feature engineering: add lagged AQI values as features
numeric_dataset['AQI_lag1'] = numeric_dataset['Overall AQI'].shift(1)
numeric_dataset['AQI_lag2'] = numeric_dataset['Overall AQI'].shift(2)

# Drop rows with missing values (due to lag features)
# data = data.dropna()

# Features and target
features = ['tempC', 'humidity', 'windspeedKmph', 'pressure', 'AQI_lag1', 'AQI_lag2']
X = numeric_dataset[features]
y = numeric_dataset['Overall AQI']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train Random Forest model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for Random Forest model: {mae}')

# Plot actual vs predicted AQI
# plt.plot(y_test.values, label='Actual AQI')
# plt.plot(y_pred, label='Predicted AQI')
# plt.legend()
# plt.show()

plt.figure(figsize=(14, 7))  # Increase dimensions here (width, height)
plt.plot(numeric_dataset.index[-len(y_test):], y_test.values, label='Actual AQI', color='red')  # Use datetime index for x-axis
plt.plot(numeric_dataset.index[-len(y_pred):], y_pred, label='Predicted AQI', color='blue')  # Use datetime index for x-axis
plt.title('Actual vs Predicted AQI', fontsize=16)  # Adding title
plt.xlabel('Time', fontsize=14)  # Label for x-axis
plt.ylabel('AQI', fontsize=14)  # Label for y-axis
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Absolute Error for Random Forest model: 12.878206635376822

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt

# Sample dataset loading (replace this with your actual data loading method)
# numeric_dataset = pd.read_csv('your_data.csv')
# Ensure 'date_time' is set as index and it's in datetime format.

# Create lagged features
numeric_dataset['AQI_lag1'] = numeric_dataset['Overall AQI'].shift(1)
numeric_dataset['AQI_lag2'] = numeric_dataset['Overall AQI'].shift(2)

# Drop rows with missing values (due to lag features)
numeric_dataset.dropna(inplace=True)

# Features and target
features = ['tempC', 'humidity', 'windspeedKmph', 'pressure', 'AQI_lag1', 'AQI_lag2']
X = numeric_dataset[features]
y = numeric_dataset['Overall AQI']  # Ensure to use the correct AQI column

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train Gradient Boosting model
model = GradientBoostingRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for Gradient Boosting model: {mae}')

# Plot actual vs predicted AQI
plt.figure(figsize=(14, 7))  # Set larger dimensions for the plot
plt.plot(numeric_dataset.index[-len(y_test):], y_test.values, label='Actual AQI', color='red')  # Use datetime index for x-axis
plt.plot(numeric_dataset.index[-len(y_pred):], y_pred, label='Predicted AQI', color='blue')  # Use datetime index for x-axis
plt.title('Actual vs Predicted AQI using Gradient Boosting Regression', fontsize=16)
plt.xlabel('Time', fontsize=14)
plt.ylabel('AQI', fontsize=14)
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Absolute Error for Gradient Boosting model: 13.163933031387616

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# Feature engineering: add lagged AQI values as features
numeric_dataset['AQI_lag1'] = numeric_dataset['Overall AQI'].shift(1)
numeric_dataset['AQI_lag2'] = numeric_dataset['Overall AQI'].shift(2)

# Drop rows with missing values (due to lag features)
numeric_dataset = numeric_dataset.dropna()

# Features and target
features = ['tempC', 'humidity', 'windspeedKmph', 'pressure', 'AQI_lag1', 'AQI_lag2']
X = numeric_dataset[features]
y = numeric_dataset['AQI']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error for Linear Regression model: {mae}')

# Plot actual vs predicted AQI
# plt.plot(y_test.values, label='Actual AQI')
# plt.plot(y_pred, label='Predicted AQI')
# plt.legend()
# plt.show()

plt.figure(figsize=(14, 7))  # Increase dimensions here (width, height)
plt.plot(numeric_dataset.index[-len(y_test):], y_test.values, label='Actual AQI', color='red')  # Use datetime index for x-axis
plt.plot(numeric_dataset.index[-len(y_pred):], y_pred, label='Predicted AQI', color='blue')  # Use datetime index for x-axis
plt.title('Actual vs Predicted AQI', fontsize=16)  # Adding title
plt.xlabel('Time', fontsize=14)  # Label for x-axis
plt.ylabel('AQI', fontsize=14)  # Label for y-axis
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Absolute Error for Linear Regression model: 14.586552876328678

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error

# Sample dataset loading (replace this with your actual data loading method)
# numeric_dataset = pd.read_csv('your_data.csv')
# Ensure 'date_time' is set as index and it's in datetime format.

# Create lagged features
numeric_dataset['AQI_lag1'] = numeric_dataset['Overall AQI'].shift(1)
numeric_dataset['AQI_lag2'] = numeric_dataset['Overall AQI'].shift(2)

# Drop rows with missing values (due to lag features)
numeric_dataset.dropna(inplace=True)

# Features and target
features = ['tempC', 'humidity', 'windspeedKmph', 'pressure', 'AQI_lag1', 'AQI_lag2']
X = numeric_dataset[features]
y = numeric_dataset['Overall AQI']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Train a model (you can use any of the models - here, Gradient Boosting is used)
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f'Random Forest Mean Absolute Error: {mae}')

# Function to predict AQI based on new inputs
def predict_aqi(tempC, humidity, windspeedKmph, pressure, aqi_lag1, aqi_lag2):
    input_data = pd.DataFrame({
        'tempC': [tempC],
        'humidity': [humidity],
        'windspeedKmph': [windspeedKmph],
        'pressure': [pressure],
        'AQI_lag1': [aqi_lag1],
        'AQI_lag2': [aqi_lag2]
    })
    
    # Predict AQI using the trained model
    predicted_aqi = model.predict(input_data)[0]
    
    return predicted_aqi

# Example of predicting AQI using the function
# Replace these values with real inputs or your own values
tempC_input = 25.4
humidity_input = 89
windspeed_input = 8.6
pressure_input = 2997
aqi_lag1_input = 27
aqi_lag2_input = 27

predicted_aqi = predict_aqi(tempC_input, humidity_input, windspeed_input, pressure_input, aqi_lag1_input, aqi_lag2_input)
print(f"Predicted AQI: {predicted_aqi}")
# Out:
# Random Forest Mean Absolute Error: 12.537482513575544
# Predicted AQI: 26.307180139720558
